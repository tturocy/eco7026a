# %% [markdown]
# ## Andrea Calef
#
#     💁‍♂️ My details: a.calef@uea.ac.uk; office hours Wednesdays 4-6pm on Teams. Or meet live by appointment!
#
# The materials for this week are available as a Jupyter notebook. Jupyter notebooks mix rich text with runnable python code. So, you can follow along with this lecture, run the python examples, and even add your own notes and code. To do this go to
#
# https://mybinder.org/v2/gh/tturocy/eco7026a/HEAD
#
# Alternatively, you can copy and paste code from here into the python command line or an IDE such as Spyder.
#
# ### Using Jupyter notebooks
#
# To get your own copy of this notebook, choose **File** above then **Download**.
#
# When you have done that, click in the field below, and either press the play button or type Shift+Enter. This executes the Python cell.

# %% [markdown]
# ## Notes: necessary libraries to replicate this lecture.
#
# pip list
# <br>
# #print(pd.__version__)
#
# import numpy as np
# <br>
# import pandas as pd
# <br>
# import os
#
# #pip install pandas_datareader
#
# #pip install pyarrow
# <br>
# import pyarrow as pa
# <br>
# import pyarrow.parquet as pq
#
# According to Pythonic and PEP-8, all the libraries should be recalled at the beginning of your .py/.ipynb file.

# %% [markdown]
# In this lecture we will upload a couple of .csv files and, at the end of it we will save part of the work via files having different extensions. Before starting any work, it is worth checking the directory ...

# %%
pwd

# %% [markdown]
# Or after importing **os** ...

# %%
#import os
os.getcwd()

# %% [markdown]
# And modify the directory as needed with:
# <br>
# cd C:\Your\Directory\Until\the\chosen\folder\
# <br>
# os.chdir('C:/Your/Directory/Until/the/chosen/folder/')
# <br>
# Let us try below!

# %% [markdown]
# Today we are going to look at **pandas** and **numpy**, which are libraries for data analysis and numerical programming, respectively.
# <br>
# <br>
# **numpy** and **pandas** provide some useful data types of their own, which rather speed up the process of data analysis.
# * numpy provides mathematical functions, multidimensional arrays.
# * pandas builds on numpy and helps us handle data for analysis.

# %% [markdown]
# ## numpy
#
# The main functionality of **numpy** is to help process **arrays**.
# <br>
# <br>
# Arrays provide a way to store data. In the previous week, we looked at lists. Arrays are a way of taking that concept and making it multi-dimensional. This concept is the same as a **matrix** in Mathematics.
# <br>
# <br>
# **numpy** is a library that stores many functions. When you wish to recall a particular one, a dot (.) is needed.
# It is worth giving a look at the **documentation** of this library by clicking on the following <a href='https://numpy.org/doc/stable/numpy-user.pdf'>hyperlink</a>.

# %%
#import numpy as np 
a = np.array([[1,2],[3,4]])
print(a)
print(a*3)

# %%
m = np.array([[2,1],[1,2]])
eigen_value, eigen_vector = np.linalg.eig(m)
print(eigen_value)
print(eigen_vector)

# %% [markdown]
# Let us import the function to do some linear algebra.

# %%
from np import linalg as la

# %% [markdown]
# We perform some matricial operations now. For a refresher, please click <a href='https://twister.caps.ou.edu/OBAN2019/Intro_FEM_files/IFEM.AppC.pdf'>here</a>.

# %%
from numpy import linalg as la 
eigen_value_, eigen_vector_ = la.eig(m)
print(eigen_value_)
print(eigen_vector_)

# %%
print(la.det(a))
det = la.det(a)
print(np.round(det))
b = la.inv(a)
print(b)
print(np.matmul(b,a))
print(np.round(np.matmul(b,a)))

# %% [markdown]
# ## pandas
#
# **pandas** is a library that builds on the mathematical tools introduced by numpy to provide a comprehensive set of statistics tools, in a similar way to software like R or STATA.
# <br>
# <br>
# We can use a public dataset as a starting point for producing some real statistics.
# <br>
# <br>
# For example, let us go on the <a href='https://fred.stlouisfed.org/'>**FRED**</a> – Federal Reserve Economic Data's website, which provides some useful macroeconomic variables we can use for analysis.
# <br>
# <br>
# We will have a look at the UK unemployment rate.
# <br>
# <br>
# The FRED website can supply us with a CSV file of the relevant variable, which we can work with if we put it in the folder in which Python is running. (We can also use Python’s **requests** module to get the file.)

# %% [markdown]
# ### pandas: Data structures
#
# Before loading our data, we need to learn about the data types available from the pandas library.
# <br>
# <br>
# pandas main data types are bool and datetime64, number64, object.
# <br>
# <br>
# pandas data types can be Series or DataFrame.
# <br>
# <br>
# A **Series** is like a column of data, whereas a DataFrame is a collection of these Series.
# <br>
# <br>
# The distinction is similar to that between a column of a spreadsheet, and the whole spreadsheet itself.

# %%
#import pandas as pd
s = pd.Series([3,2,3,4], name='inflation')
print(s)
s = pd.Series([3,2,3,4], name='inflation', index = [2008, 2009, 2010, 2011])
print(s[2008])
print(s.loc[2008:2010])

# %% [markdown]
# The Series object is much like a numpy array, but it supports the use of labeling our data with an index <u>and</u> some descriptive statistics features.

# %%
print(s.describe())
print(s.count())
print(s.mean())
print(s.median())
print(s.std())
print(s.min())
print(s.quantile(0.25))
print(s.max())

print(s.mode())
print(s.skew())
print(s.kurt())

# %% [markdown]
# If the file is stored online on GitHub, just import the file, careful to its extension.
# <br>
# If the file is stored on your computer
# <br>
# import os
# <br>
# os. getcwd()
# <br>
# #os.chdir('C:/Users/andre/Dropbox/University/Teaching/UEA/Module organiser/ECO-7026A Programming and Data Analytics for Behavioural Economists/Lecture 02')

# %%
url = 'https://raw.githubusercontent.com/tturocy/eco7026a/main/week2/LRHUTTTTGBM156S.csv'
df = pd.read_csv(url)

# %%
print(df)

# %%
usa_data = pd.read_csv('https://raw.githubusercontent.com/tturocy/eco7026a/main/week2/LRHUTTTTUSM156S.csv')

# %% [markdown]
# Let us give a look at the first four observations ...

# %%
usa_data.head(4)

# %% [markdown]
# ... and the last four ones.

# %%
usa_data.tail(4)

# %%
world_data = df.merge(usa_data,sort=True) # The merge considers just the dates in common. 
world_data.head(8)

# %%
world_data1 = df.merge(usa_data,how='outer') # The merge considers the longest time period and generates Nan for the variables with shorter time periods. 
world_data1.head(8)

# %% [markdown]
# We notice that data are not well sorted. Why? What can we do to correct?

# %%
world_data1 = world_data1.sort_values(by=['DATE']) # This column sorts world_data1 DataFrame by column Date. 
world_data1.head(8)

# %%
world_data1.index = range(len(world_data1.index))
world_data1.head(8)

# %% [markdown]
# Alternative solution
#
# world_data1.reset_index(drop=True, inplace = True) # This command resets the index. The change is permanement with the option inplace=True.
# world_data1.head(8)
#
# There are other two solutions, one is written below. See again above to look for the other one ...

# %%
world_data1 = df.merge(usa_data,how='outer', sort = True) # This is ok, only because data sets were already sorted by Date.
world_data1.head(8)
# Out:
#          DATE  LRHUTTTTGBM156S  LRHUTTTTUSM156S
# 0  1960-01-01              NaN              5.2
# 1  1960-02-01              NaN              4.8
# 2  1960-03-01              NaN              5.4
# 3  1960-04-01              NaN              5.2
# 4  1960-05-01              NaN              5.1
# 5  1960-06-01              NaN              5.4
# 6  1960-07-01              NaN              5.5
# 7  1960-08-01              NaN              5.6

# %% [markdown]
# Let us rename the two main variables of our data set.

# %%
world_data.rename(columns={'LRHUTTTTGBM156S': 'uk_unemployment', 'LRHUTTTTUSM156S': 'usa_nemployment'})

# %% [markdown]
# Do you notice anything above?
# <br>
# Let us see all the data below.

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None): print(world_data)

# %% [markdown]
# Nice, but ...

# %%
world_data.rename(columns={'LRHUTTTTGBM156S': 'uk_unemployment', 'LRHUTTTTUSM156S': 'usa_unemployment'}, inplace = True)

# %%
print(world_data['usa_unemployment'])

# %% [markdown]
# Without the option "inplace = True", the change in the name of the column is temporary and not fixed in the dataframe.

# %% [markdown]
# **DataFrame.assign()** adds one or more columns. It can contain functions and/or operations inside.

# %%
world_data = world_data.assign(Source = 'FRED', Diff_U = world_data.uk_unemployment - world_data.usa_unemployment)

# %% [markdown]
# Let us better understand the data set we are using before undertaking any analysis.

# %%
world_data.dtypes

# %%
world_data.shape

# %%
world_data.info()

# %%
world_data1.info()

# %%
world_data1.isna()

# %% [markdown]
# Does this remind you anything from the last lecture?

# %%
world_data1.isna().mean()*100

# %%
world_data.nunique()

# %% [markdown]
# **DataFrame.dtypes** is a subset of **DataFrame.info()**

# %%
import datetime
world_data['date'] = pd.to_datetime(world_data['DATE'], yearfirst = True, format='%Y-%m-%d') # it creates a datetime64[ns] variable. 
world_data['day'] = world_data['date'].dt.day
world_data['month'] = world_data['date'].dt.month
world_data['year'] = world_data['date'].dt.year
world_data['weekday'] = world_data['date'].dt.dayofweek

# %%
world_data.dtypes
# Out:
# DATE                        object
# uk_unemployment            float64
# usa_unemployment           float64
# Source                      object
# Diff_U                     float64
# date                datetime64[ns]
# day                          int64
# month                        int64
# year                         int64
# weekday                      int64
# dtype: object

# %%
world_data[['DATE','weekday']] # note the double square parenthesis, when you recall more than a column.

# %%
world_data = world_data.set_index(['DATE'])
world_data
# Out:
#             uk_unemployment  usa_unemployment Source  Diff_U       date  day  \
# DATE
# 1983-01-01             10.7              10.4   FRED     0.3 1983-01-01    1
# 1983-02-01             10.8              10.4   FRED     0.4 1983-02-01    1
# 1983-03-01             10.8              10.3   FRED     0.5 1983-03-01    1
# 1983-04-01             11.0              10.2   FRED     0.8 1983-04-01    1
# 1983-05-01             10.9              10.1   FRED     0.8 1983-05-01    1
# ...                     ...               ...    ...     ...        ...  ...
# 2019-11-01              3.7               3.5   FRED     0.2 2019-11-01    1
# 2019-12-01              3.7               3.5   FRED     0.2 2019-12-01    1
# 2020-01-01              3.9               3.6   FRED     0.3 2020-01-01    1
# 2020-02-01              3.9               3.5   FRED     0.4 2020-02-01    1
# 2020-03-01              3.8               4.4   FRED    -0.6 2020-03-01    1
#
#             month  year  weekday
# DATE
# 1983-01-01      1  1983        5
# 1983-02-01      2  1983        1
# 1983-03-01      3  1983        1
# 1983-04-01      4  1983        4
# 1983-05-01      5  1983        6
# ...           ...   ...      ...
# 2019-11-01     11  2019        4
# 2019-12-01     12  2019        6
# 2020-01-01      1  2020        2
# 2020-02-01      2  2020        5
# 2020-03-01      3  2020        6
#
# [447 rows x 9 columns]

# %%
nineties_data = world_data.loc['1990-01-01':'1999-12-01']
nineties_data
# Out:
#             uk_unemployment  usa_unemployment Source  Diff_U       date  day  \
# DATE
# 1990-01-01              6.8               5.4   FRED     1.4 1990-01-01    1
# 1990-02-01              6.8               5.3   FRED     1.5 1990-02-01    1
# 1990-03-01              6.7               5.2   FRED     1.5 1990-03-01    1
# 1990-04-01              6.8               5.4   FRED     1.4 1990-04-01    1
# 1990-05-01              6.7               5.4   FRED     1.3 1990-05-01    1
# ...                     ...               ...    ...     ...        ...  ...
# 1999-08-01              5.9               4.2   FRED     1.7 1999-08-01    1
# 1999-09-01              5.7               4.2   FRED     1.5 1999-09-01    1
# 1999-10-01              5.8               4.1   FRED     1.7 1999-10-01    1
# 1999-11-01              5.7               4.1   FRED     1.6 1999-11-01    1
# 1999-12-01              5.8               4.0   FRED     1.8 1999-12-01    1
#
#             month  year  weekday
# DATE
# 1990-01-01      1  1990        0
# 1990-02-01      2  1990        3
# 1990-03-01      3  1990        3
# 1990-04-01      4  1990        6
# 1990-05-01      5  1990        1
# ...           ...   ...      ...
# 1999-08-01      8  1999        6
# 1999-09-01      9  1999        2
# 1999-10-01     10  1999        4
# 1999-11-01     11  1999        0
# 1999-12-01     12  1999        2
#
# [120 rows x 9 columns]

# %%
nineties_data_reduced = world_data.loc['1990-01-01':'1999-12-01', world_data.columns != 'day']
nineties_data_reduced

# %%
nineties_data_reduced = world_data.loc['1990-01-01':'1999-12-01',['date','uk_unemployment','usa_unemployment','weekday']]
nineties_data_reduced

# %%
world_data.rename(columns={'LRHUTTTTGBM156S': 'uk_unemployment', 'LRHUTTTTUSM156S': 'usa_unemployment'}, inplace = True)
nineties_data_reduced = world_data.loc['1990-01-01':'1999-12-01',['date','uk_unemployment','usa_unemployment','weekday']]
nineties_data_reduced

# %%
nineties_data['UK Unemployment'].mean()
nineties_data['USA Unemployment'].mean()
nineties_data[['UK Unemployment','USA Unemployment']].mean()
nineties_data.describe(exclude=['int64','datetime64[ns]'])

# %%
nineties_data = world_data.loc['1990-01-01':'1999-12-01']
nineties_data['UK Unemployment'].mean()

# %%
nineties_data['USA Unemployment'].mean()

# %%
nineties_data[['UK Unemployment','USA Unemployment']].mean()

# %%
nineties_data.describe(exclude=['int64','datetime64[ns]'])

# %%
from pandas_datareader import wb
matches = wb.search('government.*debt.*gdp')
matches
# Out:
#                       id                                       name unit  \
# 6804   GB.DOD.TOTL.GD.ZS  Central government debt, total (% of GDP)
# 6805  GB.DOD.TOTL.GDP.ZS  Central government debt, total (% of GDP)
# 6910   GC.DOD.TOTL.GD.ZS  Central government debt, total (% of GDP)
#
#                             source  \
# 6804         WDI Database Archives
# 6805         WDI Database Archives
# 6910  World Development Indicators
#
#                                              sourceNote  \
# 6804
# 6805
# 6910  Debt is the entire stock of direct government ...
#
#                                      sourceOrganization  \
# 6804                                                b''
# 6805                                                b''
# 6910  b'International Monetary Fund, Government Fina...
#
#                                  topics
# 6804
# 6805
# 6910  Economy & Growth ; Public Sector

# %%
debt = wb.download(indicator='GC.DOD.TOTL.GD.ZS', country="all", start=2005, end=2016)
debt

# %%
debt = wb.download(indicator='GC.DOD.TOTL.GD.ZS', country="all", start=2005, end=2016).stack().unstack(0)
debt
# Out:
# country                 Caribbean small states  \
# year
# 2005 GC.DOD.TOTL.GD.ZS                     NaN
# 2006 GC.DOD.TOTL.GD.ZS               48.527819
# 2007 GC.DOD.TOTL.GD.ZS               47.400555
# 2008 GC.DOD.TOTL.GD.ZS                     NaN
# 2009 GC.DOD.TOTL.GD.ZS                     NaN
# 2010 GC.DOD.TOTL.GD.ZS                     NaN
# 2011 GC.DOD.TOTL.GD.ZS                     NaN
# 2012 GC.DOD.TOTL.GD.ZS                     NaN
# 2013 GC.DOD.TOTL.GD.ZS                     NaN
# 2014 GC.DOD.TOTL.GD.ZS                     NaN
# 2015 GC.DOD.TOTL.GD.ZS                     NaN
# 2016 GC.DOD.TOTL.GD.ZS                     NaN
#
# country                 Europe & Central Asia (excluding high income)  \
# year
# 2005 GC.DOD.TOTL.GD.ZS                                            NaN
# 2006 GC.DOD.TOTL.GD.ZS                                            NaN
# 2007 GC.DOD.TOTL.GD.ZS                                            NaN
# 2008 GC.DOD.TOTL.GD.ZS                                      18.001120
# 2009 GC.DOD.TOTL.GD.ZS                                      22.389435
# 2010 GC.DOD.TOTL.GD.ZS                                      20.993859
# 2011 GC.DOD.TOTL.GD.ZS                                      20.094904
# 2012 GC.DOD.TOTL.GD.ZS                                      19.469888
# 2013 GC.DOD.TOTL.GD.ZS                                      17.987575
# 2014 GC.DOD.TOTL.GD.ZS                                      20.345787
# 2015 GC.DOD.TOTL.GD.ZS                                      21.945159
# 2016 GC.DOD.TOTL.GD.ZS                                      22.826654
#
# country                 Europe & Central Asia (IDA & IBRD countries)  \
# year
# 2005 GC.DOD.TOTL.GD.ZS                                           NaN
# 2006 GC.DOD.TOTL.GD.ZS                                           NaN
# 2007 GC.DOD.TOTL.GD.ZS                                           NaN
# 2008 GC.DOD.TOTL.GD.ZS                                     18.597792
# 2009 GC.DOD.TOTL.GD.ZS                                     23.425111
# 2010 GC.DOD.TOTL.GD.ZS                                     22.580092
# 2011 GC.DOD.TOTL.GD.ZS                                     22.101109
# 2012 GC.DOD.TOTL.GD.ZS                                     21.777398
# 2013 GC.DOD.TOTL.GD.ZS                                     20.658630
# 2014 GC.DOD.TOTL.GD.ZS                                     23.083376
# 2015 GC.DOD.TOTL.GD.ZS                                     24.546068
# 2016 GC.DOD.TOTL.GD.ZS                                     25.385269
#
# country                 High income  North America  OECD members  \
# year
# 2005 GC.DOD.TOTL.GD.ZS    67.514647      55.641220     67.552922
# 2006 GC.DOD.TOTL.GD.ZS    65.836828      54.424774     66.023954
# 2007 GC.DOD.TOTL.GD.ZS    65.672959      54.249387     65.911099
# 2008 GC.DOD.TOTL.GD.ZS    72.684522      62.118862     71.969950
# 2009 GC.DOD.TOTL.GD.ZS    85.034118      73.827948     84.187276
# 2010 GC.DOD.TOTL.GD.ZS    91.046474      82.189046     90.037092
# 2011 GC.DOD.TOTL.GD.ZS    97.078882      86.442315     95.685822
# 2012 GC.DOD.TOTL.GD.ZS   100.082318      90.343187     98.614801
# 2013 GC.DOD.TOTL.GD.ZS   100.307890      91.804397     99.751250
# 2014 GC.DOD.TOTL.GD.ZS   104.176166      91.887488    102.339488
# 2015 GC.DOD.TOTL.GD.ZS   104.759709      92.858690    102.866838
# 2016 GC.DOD.TOTL.GD.ZS   106.823242      94.602740    104.996517
#
# country                 Post-demographic dividend  South Asia  \
# year
# 2005 GC.DOD.TOTL.GD.ZS                  67.942422   63.096878
# 2006 GC.DOD.TOTL.GD.ZS                  66.338816   60.560896
# 2007 GC.DOD.TOTL.GD.ZS                  66.186222   58.281438
# 2008 GC.DOD.TOTL.GD.ZS                  72.916878   57.099081
# 2009 GC.DOD.TOTL.GD.ZS                  85.253423   56.356526
# 2010 GC.DOD.TOTL.GD.ZS                  91.205898   52.116468
# 2011 GC.DOD.TOTL.GD.ZS                  97.083920   52.273975
# 2012 GC.DOD.TOTL.GD.ZS                  99.960060   51.349863
# 2013 GC.DOD.TOTL.GD.ZS                 101.221339   51.093928
# 2014 GC.DOD.TOTL.GD.ZS                 104.248720   50.712231
# 2015 GC.DOD.TOTL.GD.ZS                 105.086281   50.998193
# 2016 GC.DOD.TOTL.GD.ZS                 107.178207   47.680245
#
# country                 South Asia (IDA & IBRD)    Albania  ...      Tonga  \
# year                                                        ...
# 2005 GC.DOD.TOTL.GD.ZS                63.096878        NaN  ...        NaN
# 2006 GC.DOD.TOTL.GD.ZS                60.560896        NaN  ...        NaN
# 2007 GC.DOD.TOTL.GD.ZS                58.281438        NaN  ...        NaN
# 2008 GC.DOD.TOTL.GD.ZS                57.099081        NaN  ...        NaN
# 2009 GC.DOD.TOTL.GD.ZS                56.356526        NaN  ...        NaN
# 2010 GC.DOD.TOTL.GD.ZS                52.116468        NaN  ...        NaN
# 2011 GC.DOD.TOTL.GD.ZS                52.273975  69.637674  ...        NaN
# 2012 GC.DOD.TOTL.GD.ZS                51.349863  63.669153  ...        NaN
# 2013 GC.DOD.TOTL.GD.ZS                51.093928  70.580770  ...  49.038084
# 2014 GC.DOD.TOTL.GD.ZS                50.712231  73.320227  ...  47.476485
# 2015 GC.DOD.TOTL.GD.ZS                50.998193  79.864418  ...  51.176080
# 2016 GC.DOD.TOTL.GD.ZS                47.680245  80.735582  ...  49.414605
#
# country                 Trinidad and Tobago    Tunisia    Turkiye    Ukraine  \
# year
# 2005 GC.DOD.TOTL.GD.ZS                  NaN  52.420530        NaN        NaN
# 2006 GC.DOD.TOTL.GD.ZS            16.803207  48.563910        NaN        NaN
# 2007 GC.DOD.TOTL.GD.ZS            15.928004  45.782470        NaN        NaN
# 2008 GC.DOD.TOTL.GD.ZS                  NaN  43.287705  40.889175  13.229954
# 2009 GC.DOD.TOTL.GD.ZS                  NaN  42.929792  48.471026  23.990034
# 2010 GC.DOD.TOTL.GD.ZS                  NaN  38.766000  45.145315  28.866637
# 2011 GC.DOD.TOTL.GD.ZS                  NaN  42.480722  40.076954  26.480820
# 2012 GC.DOD.TOTL.GD.ZS                  NaN  42.519754  37.960229  32.445912
# 2013 GC.DOD.TOTL.GD.ZS                  NaN        NaN  32.121645  35.631400
# 2014 GC.DOD.TOTL.GD.ZS                  NaN        NaN  31.346417  63.665319
# 2015 GC.DOD.TOTL.GD.ZS                  NaN        NaN  29.060064  70.258838
# 2016 GC.DOD.TOTL.GD.ZS                  NaN        NaN  30.073550  71.809545
#
# country                 United Arab Emirates  United Kingdom  United States  \
# year
# 2005 GC.DOD.TOTL.GD.ZS                   NaN       90.446724      56.538848
# 2006 GC.DOD.TOTL.GD.ZS                   NaN       90.238447      55.467336
# 2007 GC.DOD.TOTL.GD.ZS                   NaN       91.710822      55.659926
# 2008 GC.DOD.TOTL.GD.ZS                   NaN      103.407032      63.815130
# 2009 GC.DOD.TOTL.GD.ZS                   NaN      121.319808      75.842048
# 2010 GC.DOD.TOTL.GD.ZS                   NaN      129.072972      84.964411
# 2011 GC.DOD.TOTL.GD.ZS                   NaN      141.584861      89.546817
# 2012 GC.DOD.TOTL.GD.ZS                   NaN      144.974860      93.649262
# 2013 GC.DOD.TOTL.GD.ZS              1.893523      139.555030      95.534688
# 2014 GC.DOD.TOTL.GD.ZS                   NaN      148.494533      95.766699
# 2015 GC.DOD.TOTL.GD.ZS                   NaN      145.613969      96.425228
# 2016 GC.DOD.TOTL.GD.ZS                   NaN      153.825030      98.504102
#
# country                   Uruguay     Zambia
# year
# 2005 GC.DOD.TOTL.GD.ZS  76.114460        NaN
# 2006 GC.DOD.TOTL.GD.ZS  69.026896        NaN
# 2007 GC.DOD.TOTL.GD.ZS  58.512061        NaN
# 2008 GC.DOD.TOTL.GD.ZS  57.252683        NaN
# 2009 GC.DOD.TOTL.GD.ZS  49.273329        NaN
# 2010 GC.DOD.TOTL.GD.ZS  44.222702  17.321511
# 2011 GC.DOD.TOTL.GD.ZS  45.351451  18.049909
# 2012 GC.DOD.TOTL.GD.ZS  43.403450  23.488919
# 2013 GC.DOD.TOTL.GD.ZS  42.740851  24.223994
# 2014 GC.DOD.TOTL.GD.ZS  44.357961  44.395868
# 2015 GC.DOD.TOTL.GD.ZS  51.186480  49.407347
# 2016 GC.DOD.TOTL.GD.ZS  46.656630  46.432894
#
# [12 rows x 90 columns]

# %%
debt1 = wb.download(indicator='GC.DOD.TOTL.GD.ZS', country="all", start=2005, end=2016).stack(dropna=False).unstack(0)
debt1

# %%
debt2 = wb.download(indicator='GC.DOD.TOTL.GD.ZS', country="all", start=2005, end=2016).unstack(0)
debt2

# %%
del [[debt1, debt2]]

# %%
debt

# %%
debt.index = debt.index.droplevel(1) # drop indicator index 
debt
# Out:
# country  Caribbean small states  \
# year
# 2005                        NaN
# 2006                  48.527819
# 2007                  47.400555
# 2008                        NaN
# 2009                        NaN
# 2010                        NaN
# 2011                        NaN
# 2012                        NaN
# 2013                        NaN
# 2014                        NaN
# 2015                        NaN
# 2016                        NaN
#
# country  Europe & Central Asia (excluding high income)  \
# year
# 2005                                               NaN
# 2006                                               NaN
# 2007                                               NaN
# 2008                                         18.001120
# 2009                                         22.389435
# 2010                                         20.993859
# 2011                                         20.094904
# 2012                                         19.469888
# 2013                                         17.987575
# 2014                                         20.345787
# 2015                                         21.945159
# 2016                                         22.826654
#
# country  Europe & Central Asia (IDA & IBRD countries)  High income  \
# year
# 2005                                              NaN    67.514647
# 2006                                              NaN    65.836828
# 2007                                              NaN    65.672959
# 2008                                        18.597792    72.684522
# 2009                                        23.425111    85.034118
# 2010                                        22.580092    91.046474
# 2011                                        22.101109    97.078882
# 2012                                        21.777398   100.082318
# 2013                                        20.658630   100.307890
# 2014                                        23.083376   104.176166
# 2015                                        24.546068   104.759709
# 2016                                        25.385269   106.823242
#
# country  North America  OECD members  Post-demographic dividend  South Asia  \
# year
# 2005         55.641220     67.552922                  67.942422   63.096878
# 2006         54.424774     66.023954                  66.338816   60.560896
# 2007         54.249387     65.911099                  66.186222   58.281438
# 2008         62.118862     71.969950                  72.916878   57.099081
# 2009         73.827948     84.187276                  85.253423   56.356526
# 2010         82.189046     90.037092                  91.205898   52.116468
# 2011         86.442315     95.685822                  97.083920   52.273975
# 2012         90.343187     98.614801                  99.960060   51.349863
# 2013         91.804397     99.751250                 101.221339   51.093928
# 2014         91.887488    102.339488                 104.248720   50.712231
# 2015         92.858690    102.866838                 105.086281   50.998193
# 2016         94.602740    104.996517                 107.178207   47.680245
#
# country  South Asia (IDA & IBRD)    Albania  ...      Tonga  \
# year                                         ...
# 2005                   63.096878        NaN  ...        NaN
# 2006                   60.560896        NaN  ...        NaN
# 2007                   58.281438        NaN  ...        NaN
# 2008                   57.099081        NaN  ...        NaN
# 2009                   56.356526        NaN  ...        NaN
# 2010                   52.116468        NaN  ...        NaN
# 2011                   52.273975  69.637674  ...        NaN
# 2012                   51.349863  63.669153  ...        NaN
# 2013                   51.093928  70.580770  ...  49.038084
# 2014                   50.712231  73.320227  ...  47.476485
# 2015                   50.998193  79.864418  ...  51.176080
# 2016                   47.680245  80.735582  ...  49.414605
#
# country  Trinidad and Tobago    Tunisia    Turkiye    Ukraine  \
# year
# 2005                     NaN  52.420530        NaN        NaN
# 2006               16.803207  48.563910        NaN        NaN
# 2007               15.928004  45.782470        NaN        NaN
# 2008                     NaN  43.287705  40.889175  13.229954
# 2009                     NaN  42.929792  48.471026  23.990034
# 2010                     NaN  38.766000  45.145315  28.866637
# 2011                     NaN  42.480722  40.076954  26.480820
# 2012                     NaN  42.519754  37.960229  32.445912
# 2013                     NaN        NaN  32.121645  35.631400
# 2014                     NaN        NaN  31.346417  63.665319
# 2015                     NaN        NaN  29.060064  70.258838
# 2016                     NaN        NaN  30.073550  71.809545
#
# country  United Arab Emirates  United Kingdom  United States    Uruguay  \
# year
# 2005                      NaN       90.446724      56.538848  76.114460
# 2006                      NaN       90.238447      55.467336  69.026896
# 2007                      NaN       91.710822      55.659926  58.512061
# 2008                      NaN      103.407032      63.815130  57.252683
# 2009                      NaN      121.319808      75.842048  49.273329
# 2010                      NaN      129.072972      84.964411  44.222702
# 2011                      NaN      141.584861      89.546817  45.351451
# 2012                      NaN      144.974860      93.649262  43.403450
# 2013                 1.893523      139.555030      95.534688  42.740851
# 2014                      NaN      148.494533      95.766699  44.357961
# 2015                      NaN      145.613969      96.425228  51.186480
# 2016                      NaN      153.825030      98.504102  46.656630
#
# country     Zambia
# year
# 2005           NaN
# 2006           NaN
# 2007           NaN
# 2008           NaN
# 2009           NaN
# 2010     17.321511
# 2011     18.049909
# 2012     23.488919
# 2013     24.223994
# 2014     44.395868
# 2015     49.407347
# 2016     46.432894
#
# [12 rows x 90 columns]

# %%
print(debt.loc["2005"].kurtosis())
print(debt.loc["2005"].skew())

# %%
debt.to_csv('debt.csv')
debt.to_stata('debt.dta')
debt.to_json('debt.json')
debt.to_pickle('debt.pkl')
debt.to_parquet('debt.parquet')

# %% [markdown]
# Where are these files?

# %%
os.getcwd()

# %%
pwd

# %%
cd

# %%
cd C:\Users\andre\Dropbox\University\Teaching\UEA\Module organiser\
